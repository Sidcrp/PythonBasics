# %% [markdown]
# # Machine Learning Basics
# In this module, you'll be acquiring and handling datasets. You will be using the Cinema Data, Salary Data and Reviews Data for the tasks in this module. <br> <br>
# **Pipeline:**
# * Acquiring the data
# * Handling files and formats
# * Data Analysis
# * Prediction
# * Analysing results

# %% [markdown]
# ## Task 1 - Data Acquisition
# * Retrieve the CinemaData dataset from Firebase, convert it to a CSV and save it in the 'Data' folder as 'CinemaData.csv'. You may use shell scripts, other packages and any other resources you require to do this. The database can be accessed with a HTTP request, ask a TA for the link. <br>
# * Using `wget`, download the 'SalaryData.txt' and save it in the 'Data' folder. Convert it to a CSV named 'SalaryData.csv' and save it in the same folder. It is avaliable at this link: <br>
# http://rebrand.ly/ml_salarydata

# %%
import requests
import numpy as np
import pandas as pd
import pickle as pkl
import csv
Url = "https://sf-mlbasics.firebaseio.com/CinemaData.json"
r = requests.get(url = Url)
data = r.json()

df = pd.DataFrame.from_dict(data)
df.to_csv(r'C:\Users\siddh\Downloads\MLBasics-master\Data\CinemaData.csv',header=True)
url = "https://gist.github.com/solarillionfoundation/4d13184683407dfb0b36c7130fce1567"     
myfile = requests.get(url)
path = (r'C:\Users\siddh\Downloads\MLBasics-master\Data\SalaryData.json')
file = open(path,"w")
file.write(myfile.text)
file.close()


df = pd.read_csv(url, sep='\t')   
df.head()
df.to_csv(r'C:\Users\siddh\Downloads\MLBasics-master\Data\SalaryData.csv',header=True)

# %% [markdown]
# ## Task 2 - Dataset Handling
# * You can find the Reviews Data in a RAR file in the 'Data' directory. Extract this dataset and use it for this module.
#
# * The dataset contains positive and negative movie reviews. The files 'Positive_Reviews.txt' and 'Negative_Reviews.txt' contain names of files having positive and negative reviews respectively. Create two directories ‘pos’ and ‘neg’, and segregate the reviews accordingly into the two directories.
#
# * Load ‘cv000_29590.csv’ and report the number of words present in the first column.
#
# * Find the number of unique words in the first column. For this task, ignore punctuations, that is, punctuations are not considered as a word or a part of it.
#
# * Lookups: OS module, String functions

# %%
import requests
import string
import numpy as np
import pandas as pd
import pickle as pkl
import csv
from zipfile import ZipFile
import io
import os
import unrar
import rarfile
from pyunpack import Archive
import shutil

rar = rarfile.RarFile(r'C:\Users\siddh\Downloads\MLBasics-master\Data\Reviews.rar')

list1 = []

list2 = []

list3 = []


Archive('Data\\Reviews.rar').extractall('Data\\')

directory_in_str = r'C:\Users\siddh\Downloads\MLBasics-master\Data\Reviews\Assignment_1_a\Reviews'

directory = os.fsencode(directory_in_str)

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".txt"): 
        list1.append(filename)
        continue
    else:
         continue
            
filename = open(r'C:\Users\siddh\Downloads\MLBasics-master\Data\Reviews\Assignment_1_a\Positive_Reviews.txt','r')

files = filename.read()

files = files.replace('"','').replace("'",'').replace('[','').replace(']','').replace(' ','')

list2 = files.split(",")
      
filename.close()


filename = open(r'C:\Users\siddh\Downloads\MLBasics-master\Data\Reviews\Assignment_1_a\Negative_Reviews.txt','r')

files = filename.read()

files = files.replace('"','').replace("'",'').replace('[','').replace(']','').replace(' ','')

list3 = files.split(",")
      
filename.close()

for i in list1 :
    if i in list2 :
        shutil.copy('C:\\Users\\siddh\\Downloads\\MLBasics-master\\Data\\Reviews\\Assignment_1_a\\Reviews\\'+i,'C:\\Users\\siddh\\Downloads\\MLBasics-master\\Data\\pos')
    elif i in list3 :
        shutil.copy('C:\\Users\\siddh\\Downloads\\MLBasics-master\\Data\\Assignment_1_a\\Reviews\\'+i,'C:\\Users\\siddh\\Downloads\\MLBasics-master\\Data\\neg')

dataframe = pd.read_csv(r"C:\Users\siddh\Downloads\MLBasics-master\Data\Assignment_1_a\Reviews\cv000_29590.txt")

dataframe

newstring = dataframe.iloc[:,0].values

countstring = " "

countstring = ' '.join(newstring)

count = 0

finalcount = 0

for i in string.punctuation :
    countstring = countstring.replace(i,'')
    
for i in range(len(countstring)) :
    if countstring[i].isspace() :
        count+=1
        
print(count+1)

countstring = countstring.split(" ")

finalcount = len(set(countstring))

print(finalcount)
# Out:
# 278
# 172
