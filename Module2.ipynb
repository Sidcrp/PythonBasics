# %% [markdown]
# # Machine Learning Basics
# In this module, you'll be analysing a dataset. You will be using the Cinema Data for the tasks in this module. <br> <br>
# **Pipeline:**
# * Acquiring the data - done
# * Handling files and formats - done
# * Data Analysis
# * Prediction
# * Analysing results

# %% [markdown]
# ## Task 1 - Plotting
# * Plot the values of occupancy percentage versus number of weeks since release, for all movies in the dataset.
# * Plot the number of other releases in the week versus occupancy percentage and weeks until the end of lifetime, for all movies.
# * Plot the number of shows in the week versus occupancy percentage and weeks until the end of lifetime, for all movies.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle as pkl
dataframe = pd.read_csv(r'C:\Users\siddh\Downloads\MLBasics-master\Data\CinemaData.csv')

dataframe = dataframe.iloc[:,:13]
 
dataframe
# Out:
#       Unnamed: 0  Capacity  DaysShowedInWeek  Index    LastDate  Lifetime  \
# 0              0      3100                 5      0  2015-12-17         2
# 1              1      3390                 7      1  2015-12-17         2
# 2              2       860                 2      2  2015-12-17         2
# 3              3       110                 1      3  2016-01-06         5
# 4              4       720                 6      4  2016-01-06         5
# ...          ...       ...               ...    ...         ...       ...
# 3505        3505       120                 1   3505  2017-11-15         0
# 3506        3506      2410                 2   3506  2017-11-18         0
# 3507        3507       330                 2   3507  2017-11-18         0
# 3508        3508       360                 2   3508  2017-11-18         0
# 3509        3509       220                 2   3509  2017-11-18         0
#
#            Movie  OccAtWeek    OccPer  OtherReleasesInWeek ReleaseDate  \
# 0     0001000001       2494  0.804516                    8  2015-12-04
# 1     0001000001       1932  0.569912                    4  2015-12-04
# 2     0001000001        222  0.258140                    4  2015-12-04
# 3     0001000002         59  0.536364                    8  2015-12-04
# 4     0001000002        630  0.875000                    7  2015-12-04
# ...          ...        ...       ...                  ...         ...
# 3505  HO00002188        112  0.933333                    7  2017-11-15
# 3506  HO00002193       2318  0.961826                    7  2017-11-17
# 3507  HO00002196        255  0.772727                    7  2017-11-17
# 3508  HO00002197        304  0.844444                    7  2017-11-17
# 3509  HO00002198        162  0.736364                    7  2017-11-17
#
#       ShowsInWeek  WeeksSinceRelease
# 0              10                  0
# 1              14                  1
# 2               4                  2
# 3               1                  0
# 4               6                  3
# ...           ...                ...
# 3505            1                  0
# 3506            9                  0
# 3507            3                  0
# 3508            3                  0
# 3509            2                  0
#
# [3510 rows x 13 columns]

# %%
Y = dataframe['OccPer']
X = dataframe['WeeksSinceRelease']

plt.ylabel(" Occupancy Percentage ")
plt.xlabel(" Number Of Weeks Since Release ")
plt.scatter(X,Y,color = 'red')
plt.show()

Y = dataframe['OtherReleasesInWeek']
X = dataframe['OccPer']
plt.ylabel(" Number Of Other Releases In The Week ")
plt.xlabel(" Occupancy Percentage ")
plt.scatter(X,Y,color = 'blue')
plt.show()

Y = dataframe['OtherReleasesInWeek']
X = dataframe['Lifetime'] - dataframe['WeeksSinceRelease']
plt.ylabel(" Number Of Other Releases In The Week ")
plt.xlabel(" Weeks Until The End Of Lifetime ")
plt.scatter(X,Y,color = 'green')
plt.show()

Y =  dataframe['ShowsInWeek']
X = dataframe['OccPer']
plt.ylabel(" Number Of Shows In The Week ")
plt.xlabel(" Occupancy Percentage ")
plt.scatter(X,Y,color = 'black')
plt.show()

Y = dataframe['ShowsInWeek']
X = dataframe['Lifetime'] - dataframe['WeeksSinceRelease']
plt.ylabel(" Number Of Shows In The Week ")
plt.xlabel(" Weeks Untill The End Of Lifetime ")
plt.scatter(X,Y,color = 'brown')
plt.show()

# %% [markdown]
# ## Task 2 - Reasoning
# Now that you have the plots, identify the correlation between the various parameters analysed. Justify the correlations, your observations, and your hypotheses for the same with appropriate reasoning.
